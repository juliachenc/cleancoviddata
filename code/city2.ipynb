# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48b64f4f-564e-40ee-a113-efc0c21ebc82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48b64f4f-564e-40ee-a113-efc0c21ebc82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving out.csv to out (1).csv

# %%
import numpy as np
import pandas as pd 
import sys
import io

# %%
df = pd.read_excel(io.BytesIO(uploaded['cleaned.xlsx']))
df = df.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-ee6c229b2eec> in <module>()
# ----> 1 df = pd.read_excel(io.BytesIO(uploaded['cleaned.xlsx']))
#       2 df = df.fillna(0)
#
# KeyError: 'cleaned.xlsx'

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
#df.to_csv('out.csv')
#!cp out.csv "drive/My Drive/"

# %%
readdata= pd.read_csv(io.BytesIO(uploaded['out.csv']))

# %%
new1= readdata.groupby(["Data Type","City/Community"]).sum()

# %%
new2= new1.unstack().transpose()

# %%
population_table = new2[0:321]
long_data = new2[321::]
population_table
# Out:
# Data Type                   Cumulative Confirmed Case Count  ...  Newly Reported Death Count
#            City/Community                                    ...
# Population Acton                                       8013  ...                        8013
#            Adams-Normandie                             8487  ...                        8487
#            Agoura Hills                               21168  ...                       21168
#            Agua Dulce                                  3975  ...                        3975
#            Alhambra                                   86706  ...                       86706
# ...                                                     ...  ...                         ...
#            Wilmington                                 57279  ...                       57279
#            Wilshire Center                            51463  ...                       51463
# ...

# %%
long_data
# Out:
# Data Type                   Cumulative Confirmed Case Count  ...  Newly Reported Death Count
#            City/Community                                    ...
# 2020-03-17 Acton                                          0  ...                           0
#            Adams-Normandie                                5  ...                           0
#            Agoura Hills                                   0  ...                           0
#            Agua Dulce                                     0  ...                           0
#            Alhambra                                       1  ...                           0
# ...                                                     ...  ...                         ...
# 2021-06-12 Wilmington                                  8488  ...                           0
#            Wilshire Center                             5642  ...                           0
# ...

# %%
population_table.to_csv('population_table.csv')
# !cp population_table.csv "drive/My Drive/"

long_data.to_csv('long_data.csv')
# !cp long_data.csv "drive/My Drive/"
