# %%
import numpy as np
import pandas as pd 
import sys
import io

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e035c5e8-04c0-4683-93cc-7d5620ab59d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e035c5e8-04c0-4683-93cc-7d5620ab59d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CaseCounts_CrudeRates_SelectedRegions_061321_2359_UNHIDE.xlsx to CaseCounts_CrudeRates_SelectedRegions_061321_2359_UNHIDE.xlsx

# %%
xls = pd.ExcelFile('/content/CaseCounts_CrudeRates_SelectedRegions_061321_2359_UNHIDE.xlsx')
df1 = pd.read_excel(xls, 'LAC_Demographics',header=None)

# %%
df1 = df1.drop([0, 1])

# %%
#df1.index = df1. iloc[:, 0]
df1.columns = df1.iloc[0,:]
df2 = df1.drop([2])

# %%
df2.to_csv('df2.csv') 
files.download('df2.csv')

# %%
df2
# Out:
# 2                                           Age Group  ... 2021-06-12 00:00:00
# 3                                             0 to 17  ...              166183
# 4                                            18 to 40  ...                 NaN
# 5                                            41 to 65  ...                 NaN
# 6                                            18 to 29  ...              291977
# 7                                            30 to 49  ...              410810
# 8                                            50 to 64  ...              237072
# 9                                         65 or Older  ...              131778
# 10       Under Investigation or Not Otherwise Listed*  ...                8487
# 11                                                Sex  ...                 NaN
# 12                                             Female  ...              632221
# 13                                               Male  ...              589958
# ...

# %% [markdown]
# ## Re group Age

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdb40c35-aa01-4652-8d58-28cf8e86cf72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdb40c35-aa01-4652-8d58-28cf8e86cf72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df2.csv to df2 (2).csv

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['df2.csv']))
df2 = df2.drop([1,2,3,4,5])

# %%
df_age = df2[0:3]
df_age
# Out:
#      Age Group 2020-03-17 2020-03-18  ... 2021-06-10 2021-06-11 2021-06-12
# 0      0 to 17          3          4  ...   166087.0   166153.0   166183.0
# 6     18 to 64        127        138  ...   939487.0   939718.0   939859.0
# 7  65 or Older         29         31  ...   131682.0   131759.0   131778.0
#
# [3 rows x 454 columns]

# %%
age = df2[0:4]
age = age.transpose()
age.columns =  age.iloc[0]
age = age.drop(age.index[0])
age = age.fillna(0)

age.iloc[:, 0] = age.iloc[:, 0].astype(np.int64)
age.iloc[:, 1] = age.iloc[:, 1].astype(np.int64)
age.iloc[:, 2] = age.iloc[:, 2].astype(np.int64)
age.iloc[:, 3] = age.iloc[:, 3].astype(np.int64)

age
# Out:
# Age Group   0 to 17  ...  Under Investigation or Not Otherwise Listed*
# 2020-03-17        3  ...                                            30
# 2020-03-18        4  ...                                            56
# 2020-03-19        4  ...                                            98
# 2020-03-20        4  ...                                            74
# 2020-03-21        5  ...                                            17
# ...             ...  ...                                           ...
# 2021-06-08   166039  ...                                          8660
# 2021-06-09   166060  ...                                          8676
# 2021-06-10   166087  ...                                          8693
# 2021-06-11   166153  ...                                          8486
# 2021-06-12   166183  ...                                          8487
#
# [453 rows x 4 columns]

# %%
age.to_csv('age.csv') 
files.download('age.csv')

# %%
df2
# Out:
#                                             Age Group  ...  2021-06-12
# 0                                             0 to 17  ...         5.0
# 6                                            18 to 64  ...      6725.0
# 7                                         65 or Older  ...     17678.0
# 8        Under Investigation or Not Otherwise Listed*  ...         6.0
# 9                                                 Sex  ...         NaN
# 10                                             Female  ...     10046.0
# 11                                               Male  ...     14176.0
# 12                                              Other  ...         4.0
# 13       Under Investigation or Not Otherwise Listed*  ...       188.0
# 14                                     Race/Ethnicity  ...         NaN
# 15                   American Indian or Alaska Native  ...        51.0
# 16                                              Asian  ...      3338.0
# ...

# %%
sex = df2[5:9]
sex = sex.transpose()
sex.columns = sex.iloc[0]
sex = sex.drop(sex.index[0])
#sex['Sex'] = age['Age Group']
#sex = sex.fillna(0)
sex
# Out:
# Age Group   Female    Male Other Under Investigation or Not Otherwise Listed*
# 2020-03-17      57     102     0                                           30
# 2020-03-18      62     111     0                                           56
# 2020-03-19      69     123     0                                           98
# 2020-03-20      97     166     0                                           77
# 2020-03-21     105     166     0                                          137
# ...            ...     ...   ...                                          ...
# 2021-06-08  631726  589557   661                                        23644
# 2021-06-09  631809  589646   661                                        23655
# 2021-06-10  631906  589707   661                                        23675
# 2021-06-11  632120  589880   661                                        23455
# 2021-06-12  632221  589958   661                                        23467
#
# [453 rows x 4 columns]

# %%
sex.to_csv('sex.csv') 
files.download('sex.csv')

# %%
race = df2[10:18]
race = race.transpose()
race.columns = race.iloc[0]
race = race.drop(race.index[0])
#race['Race/Ethnicity'] = age['Age Group']
race = race.fillna(0)

#race.iloc[:, 7] = race.iloc[:, 7].astype(np.int64)
#race.iloc[:, 8] = race.iloc[:, 8].astype(np.int64)
race
# Out:
# Age Group  American Indian or Alaska Native  ... Under Investigation or Not Otherwise Listed*
# 2020-03-17                                0  ...                                          189
# 2020-03-18                                0  ...                                          229
# 2020-03-19                                0  ...                                          290
# 2020-03-20                                0  ...                                          340
# 2020-03-21                                0  ...                                          408
# ...                                     ...  ...                                          ...
# 2021-06-08                             2007  ...                                       226324
# 2021-06-09                             2007  ...                                       226336
# 2021-06-10                             2007  ...                                       226371
# ...

# %%
from google.colab import files

race.to_csv('race.csv') 
files.download('race.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
